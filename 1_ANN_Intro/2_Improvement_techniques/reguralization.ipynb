# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import tensorflow
from tensorflow import keras
from keras.layers import Dense,Dropout
from keras import Sequential

# %%
from keras.regularizers import  l1,l2,l1_l2

# %%
cancer = load_breast_cancer()

df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
df['target'] = cancer.target

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split

X=cancer.data
y=cancer.target

X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2)

# %%
model=Sequential([
    Dense(128,input_dim=30,activation='relu',kernel_regularizer=l1(0.5)),
    Dense(64,activation='relu',kernel_regularizer=l1(0.5)),
    Dense(8,activation='relu',kernel_regularizer=l1_l2(l1=0.5,l2=0.5)),
    Dense(1,activation='sigmoid'),
])
# Out:
# d:\PYTHON\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=25,validation_split=0.2)
# Out:
# Epoch 1/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6018 - loss: 582.4142 - val_accuracy: 0.4286 - val_loss: 528.3405
# Epoch 2/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6364 - loss: 513.2853 - val_accuracy: 0.7253 - val_loss: 468.3066
# Epoch 3/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8546 - loss: 454.4805 - val_accuracy: 0.8681 - val_loss: 412.3777
# Epoch 4/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8461 - loss: 399.5533 - val_accuracy: 0.9231 - val_loss: 360.1815
# Epoch 5/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8702 - loss: 348.3087 - val_accuracy: 0.9121 - val_loss: 311.7459
# Epoch 6/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8564 - loss: 300.8538 - val_accuracy: 0.8242 - val_loss: 267.3663
# Epoch 7/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8484 - loss: 257.2703 - val_accuracy: 0.9121 - val_loss: 226.7591
# Epoch 8/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8825 - loss: 217.7206 - val_accuracy: 0.9451 - val_loss: 190.3856
# Epoch 9/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8852 - loss: 182.3516 - val_accuracy: 0.9451 - val_loss: 158.0650
# Epoch 10/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9114 - loss: 150.9514 - val_accuracy: 0.9341 - val_loss: 129.8040
# Epoch 11/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8933 - loss: 123.7725 - val_accuracy: 0.9341 - val_loss: 105.7109
# Epoch 12/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8840 - loss: 100.7168 - val_accuracy: 0.8242 - val_loss: 86.1023
# Epoch 13/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7549 - loss: 82.2976 - val_accuracy: 0.5934 - val_loss: 70.9909
# Epoch 14/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7024 - loss: 68.0456 - val_accuracy: 0.8791 - val_loss: 59.4520
# Epoch 15/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8257 - loss: 57.6845 - val_accuracy: 0.9451 - val_loss: 52.2856
# Epoch 16/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8864 - loss: 50.9581 - val_accuracy: 0.9451 - val_loss: 47.0290
# Epoch 17/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9256 - loss: 46.1268 - val_accuracy: 0.8901 - val_loss: 43.2583
# Epoch 18/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9005 - loss: 42.4740 - val_accuracy: 0.9451 - val_loss: 39.9511
# Epoch 19/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9085 - loss: 39.2721 - val_accuracy: 0.8901 - val_loss: 37.0775
# Epoch 20/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8571 - loss: 36.4973 - val_accuracy: 0.7582 - val_loss: 34.6733
# Epoch 21/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7243 - loss: 34.1808 - val_accuracy: 0.8681 - val_loss: 32.2294
# Epoch 22/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8852 - loss: 31.7373 - val_accuracy: 0.9451 - val_loss: 30.0023
# Epoch 23/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9177 - loss: 29.5890 - val_accuracy: 0.8681 - val_loss: 28.1377
# Epoch 24/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8118 - loss: 27.7556 - val_accuracy: 0.9341 - val_loss: 26.3755
# Epoch 25/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8995 - loss: 26.0430 - val_accuracy: 0.9011 - val_loss: 24.8672
